# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-98733620-8e28-4f76-ac05-15a6afd2a765" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98733620-8e28-4f76-ac05-15a6afd2a765">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Movie_collection_train.csv to Movie_collection_train (2).csv

# %%
import pandas as pd

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['Movie_collection_train.csv']))

# %%
df2.shape
# Out:
# (400, 19)

# %%
df2.head()
# Out:
#    Collection  Marketin_expense  ...  Num_multiplex  3D_available
# 0       48000           20.1264  ...            494           YES
# 1       43200           20.5462  ...            462            NO
# 2       69400           20.5458  ...            458            NO
# 3       66800           20.6474  ...            472           YES
# 4       72400           21.3810  ...            395            NO
#
# [5 rows x 19 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           400 non-null    int64
#  1   Marketin_expense     400 non-null    float64
#  2   Production_expense   400 non-null    float64
#  3   Multiplex_coverage   400 non-null    float64
#  4   Budget               400 non-null    float64
#  5   Movie_length         400 non-null    float64
#  6   Lead_ Actor_Rating   400 non-null    float64
#  7   Lead_Actress_rating  400 non-null    float64
#  8   Director_rating      400 non-null    float64
#  9   Producer_rating      400 non-null    float64
#  10  Critic_rating        400 non-null    float64
#  11  Trailer_views        400 non-null    int64
#  12  Time_taken           392 non-null    float64
#  13  Twitter_hastags      400 non-null    float64
#  14  Genre                400 non-null    object
# ...

# %%
df2.index.name = 'index_movie'

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=400, step=1, name='index_movie')

# %%
df2.columns
# Out:
# Index(['Collection', 'Marketin_expense', 'Production_expense',
#        'Multiplex_coverage', 'Budget', 'Movie_length', 'Lead_ Actor_Rating',
#        'Lead_Actress_rating', 'Director_rating', 'Producer_rating',
#        'Critic_rating', 'Trailer_views', 'Time_taken', 'Twitter_hastags',
#        'Genre', 'Avg_age_actors', 'MPAA_film_rating', 'Num_multiplex',
#        '3D_available'],
#       dtype='object')

# %%
df2.loc[df2.Collection >= 100000]
# Out:
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 161              100000           49.2672  ...            539           YES
# 162              100000           56.6754  ...            557           YES
# 163              100000           50.3804  ...            603           YES
# 166              100000           60.2038  ...            522           YES
# 186              100000           21.1204  ...            458           YES
# 195              100000           20.2762  ...            430           YES
# 204              100000           20.4018  ...            442           YES
# 225              100000           30.5386  ...            570           YES
# 257              100000           32.2308  ...            552           YES
# 267              100000           31.5668  ...            633           YES
# 283              100000           20.3002  ...            489           YES
# ...

# %%
df2.loc[1:3]
# Out:
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 1                 43200           20.5462  ...            462            NO
# 2                 69400           20.5458  ...            458            NO
# 3                 66800           20.6474  ...            472           YES
#
# [3 rows x 19 columns]

# %%
df2.iloc[0:10]
# Out:
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 0                 48000           20.1264  ...            494           YES
# 1                 43200           20.5462  ...            462            NO
# 2                 69400           20.5458  ...            458            NO
# 3                 66800           20.6474  ...            472           YES
# 4                 72400           21.3810  ...            395            NO
# 5                 57400           20.5970  ...            460           YES
# 6                 45800           21.7658  ...            522           YES
# 7                 44200           22.8910  ...            571            NO
# 8                 33000           24.2248  ...            564           YES
# 9                 37800           23.4008  ...            508           YES
#
# [10 rows x 19 columns]

# %%
df2.iloc[[0,4]]
# Out:
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 0                 48000           20.1264  ...            494           YES
# 4                 72400           21.3810  ...            395            NO
#
# [2 rows x 19 columns]

# %%
df2.groupby('Collection')

# %%
df2.groupby('Collection').groups
# Out:
# {10000: Int64Index([398], dtype='int64', name='index_movie'),
#  12600: Int64Index([399], dtype='int64', name='index_movie'),
#  14400: Int64Index([385], dtype='int64', name='index_movie'),
#  14800: Int64Index([387], dtype='int64', name='index_movie'),
#  17000: Int64Index([397], dtype='int64', name='index_movie'),
#  17600: Int64Index([384], dtype='int64', name='index_movie'),
#  19400: Int64Index([392], dtype='int64', name='index_movie'),
#  20400: Int64Index([379, 388], dtype='int64', name='index_movie'),
#  20800: Int64Index([380], dtype='int64', name='index_movie'),
#  21000: Int64Index([386], dtype='int64', name='index_movie'),
#  21800: Int64Index([381], dtype='int64', name='index_movie'),
#  22600: Int64Index([382], dtype='int64', name='index_movie'),
#  23000: Int64Index([389], dtype='int64', name='index_movie'),
#  23600: Int64Index([144], dtype='int64', name='index_movie'),
#  24600: Int64Index([383], dtype='int64', name='index_movie'),
# ...

# %%
df2.groupby(['Collection','Budget']).groups
# Out:
# {(10000, 30291.415): Int64Index([398], dtype='int64', name='index_movie'),
#  (12600, 32507.86): Int64Index([399], dtype='int64', name='index_movie'),
#  (14400, 29313.735): Int64Index([385], dtype='int64', name='index_movie'),
#  (14800, 27775.0): Int64Index([387], dtype='int64', name='index_movie'),
#  (17000, 31924.585): Int64Index([397], dtype='int64', name='index_movie'),
#  (17600, 24264.24): Int64Index([384], dtype='int64', name='index_movie'),
#  (19400, 27974.98): Int64Index([392], dtype='int64', name='index_movie'),
#  (20400, 27108.4): Int64Index([388], dtype='int64', name='index_movie'),
#  (20400, 34568.765): Int64Index([379], dtype='int64', name='index_movie'),
#  (20800, 38707.24): Int64Index([380], dtype='int64', name='index_movie'),
#  (21000, 25841.86): Int64Index([386], dtype='int64', name='index_movie'),
#  (21800, 36357.475): Int64Index([381], dtype='int64', name='index_movie'),
#  (22600, 30752.48): Int64Index([382], dtype='int64', name='index_movie'),
# ...

# %%
grouped = df2.groupby('Collection')
for movie,group in grouped:
  print(movie) 
  print(group)
# Out:
# 10000
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 398               10000           787.036  ...            653            NO
#
# [1 rows x 19 columns]
# 12600
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 399               12600           218.331  ...            613            NO
#
# [1 rows x 19 columns]
# 14400
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 385               14400           356.236  ...            600            NO
#
# [1 rows x 19 columns]
# 14800
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 387               14800           471.942  ...            617            NO
#
# [1 rows x 19 columns]
# 17000
# ...

# %%
grouped = df2.groupby('Collection')
print(grouped.get_group(32400))
# Out:
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 127               32400           25.1830  ...            567           YES
# 315               32400           25.0712  ...            559            NO
#
# [2 rows x 19 columns]

# %%
grouped = df2.groupby('Collection')
avg = lambda x: (x - x.mean())/ x.std()*10
print(grouped.transform(avg))
# Out:
#              Marketin_expense  ...  Num_multiplex
# index_movie                    ...
# 0                   -7.071068  ...      -7.071068
# 1                   -7.071068  ...      -7.071068
# 2                         NaN  ...            NaN
# 3                   -7.071068  ...      -7.071068
# 4                    7.071068  ...      -7.071068
# ...                       ...  ...            ...
# 395                 -0.265720  ...       5.752098
# 396                       NaN  ...            NaN
# 397                       NaN  ...            NaN
# 398                       NaN  ...            NaN
# 399                       NaN  ...            NaN
#
# [400 rows x 15 columns]

# %%
df2.groupby('Collection').filter(lambda x: len(x) >= 10)
# Out:
#              Collection  Marketin_expense  ...  Num_multiplex  3D_available
# index_movie                                ...
# 161              100000           49.2672  ...            539           YES
# 162              100000           56.6754  ...            557           YES
# 163              100000           50.3804  ...            603           YES
# 166              100000           60.2038  ...            522           YES
# 186              100000           21.1204  ...            458           YES
# 195              100000           20.2762  ...            430           YES
# 204              100000           20.4018  ...            442           YES
# 225              100000           30.5386  ...            570           YES
# 257              100000           32.2308  ...            552           YES
# 267              100000           31.5668  ...            633           YES
# 283              100000           20.3002  ...            489           YES
# ...
